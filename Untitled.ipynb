# %%
import pandas as pd
cs = pd.read_csv('/Users/Vagif/Downloads/merged2.csv')

cs
# Out:
#       movieId                           title  \
# 0           1                Toy Story (1995)
# 1           1                Toy Story (1995)
# 2           1                Toy Story (1995)
# 3           2                  Jumanji (1995)
# 4           2                  Jumanji (1995)
# ...       ...                             ...
# 3678   187595  Solo: A Star Wars Story (2018)
# 3679   193565       Gintama: The Movie (2010)
# 3680   193565       Gintama: The Movie (2010)
# 3681   193565       Gintama: The Movie (2010)
# 3682   193565       Gintama: The Movie (2010)
#
#                                            genres  userId               tag  \
# 0     Adventure|Animation|Children|Comedy|Fantasy     336             pixar
# 1     Adventure|Animation|Children|Comedy|Fantasy     474             pixar
# 2     Adventure|Animation|Children|Comedy|Fantasy     567               fun
# 3                      Adventure|Children|Fantasy      62           fantasy
# ...

# %%
import numpy as np
cs[['title']].apply(pd.Series.unique).join(cs[['genres','tag']])
# Out:
#                                    title  \
# 0                       Toy Story (1995)
# 1                         Jumanji (1995)
# 2                Grumpier Old Men (1995)
# 3     Father of the Bride Part II (1995)
# 4                         Sabrina (1995)
# ...                                  ...
# 1567                   Game Night (2018)
# 1568                  Tomb Raider (2018)
# 1569                   Deadpool 2 (2018)
# 1570      Solo: A Star Wars Story (2018)
# 1571           Gintama: The Movie (2010)
#
#                                            genres               tag
# 0     Adventure|Animation|Children|Comedy|Fantasy             pixar
# 1     Adventure|Animation|Children|Comedy|Fantasy             pixar
# 2     Adventure|Animation|Children|Comedy|Fantasy               fun
# 3                      Adventure|Children|Fantasy           fantasy
# 4                      Adventure|Children|Fantasy  magic board game
# ...

# %%
df = pd.read_csv('/Users/Vagif/Downloads/disney_plus_shows.csv')

# %%
df[['title']].apply(pd.Series.unique).join(df[['genre','plot','director','actors','writer']])
# Out:
#                                           title  \
# 0                    10 Things I Hate About You
# 1                          101 Dalmatian Street
# 2                                101 Dalmatians
# 3    101 Dalmatians 2: Patch's London Adventure
# 4                                102 Dalmatians
# ..                                          ...
# 868                                      Zapped
# 869             Zenon: Girl of the 21st Century
# 870                           Zenon: The Zequel
# 871                                   Zenon: Z3
# 872                                    Zootopia
#
#                                              genre  \
# 0                           Comedy, Drama, Romance
# 1                        Animation, Comedy, Family
# 2                 Adventure, Comedy, Crime, Family
# 3    Animation, Adventure, Comedy, Family, Musical
# 4                        Adventure, Comedy, Family
# ..                                             ...
# ...

# %%
df
# Out:
#        imdb_id                                       title  \
# 0    tt0147800                  10 Things I Hate About You
# 1    tt7019028                        101 Dalmatian Street
# 2    tt0115433                              101 Dalmatians
# 3    tt0324941  101 Dalmatians 2: Patch's London Adventure
# 4    tt0211181                              102 Dalmatians
# ..         ...                                         ...
# 987  tt3544734                                      Zapped
# 988  tt0186726             Zenon: Girl of the 21st Century
# 989  tt0271271                           Zenon: The Zequel
# 990  tt0379060                                   Zenon: Z3
# 991  tt2948356                                    Zootopia
#
#                                                   plot    type  rated   year  \
# 0    A pretty, popular teenager can't go out on a d...   movie  PG-13   1999
# 1    This series follows the lives of Delilah and D...  series    NaN  2018–
# ...
